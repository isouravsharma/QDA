# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# x = []
# [x.append(np.random.choice(100)) for i in range(101)]

# %%
y = []
[y.append(math.sin(i)) for i in x]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
y
# Out:
# [0.6367380071391379,
#  0.5514266812416906,
#  0.7331903200732921,
#  -0.7794660696158047,
#  0.5139784559875352,
#  -0.9992068341863537,
#  -0.9589242746631385,
#  -0.5365729180004349,
#  -0.8218178366308225,
#  0.683261714736121,
#  0.9893582466233818,
#  0.14987720966295234,
#  0.8509035245341184,
#  -0.9999902065507035,
#  0.0,
#  0.9637953862840878,
#  -0.5440211108893699,
#  -0.7794660696158047,
#  0.8939966636005579,
#  0.956375928404503,
#  -0.9055783620066239,
#  0.9683644611001854,
#  0.017701925105413577,
#  -0.26237485370392877,
#  0.5139784559875352,
#  -0.27941549819892586,
#  0.5290826861200238,
#  0.27090578830786904,
#  -0.9234584470040598,
#  0.4201670368266409,
#  -0.9992068341863537,
#  0.9017883476488092,
#  0.2963685787093853,
#  -0.750987246771676,
#  0.123573122745224,
#  0.8939966636005579,
#  -0.9661177700083929,
#  -0.9992068341863537,
#  -0.9537526527594719,
#  -0.5587890488516162,
#  0.9906073556948704,
#  0.9200260381967907,
#  -0.008851309290403876,
# ...

# %%
plt.scatter(x, y)

# %%
plt.scatter(1, math.sin(1))
