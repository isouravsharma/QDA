# %%
pip install feedparser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=88ea88c5bc7c240977e56eee9affce1acaae1e8838db5cc33bdd602eae0bb249
#   Stored in directory: /Users/sousharma/Library/Caches/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import feedparser

# RSS feed URL from Moneycontrol (example: Business news feed)
# url = 'https://www.moneycontrol.com/rss/latestnews.xml'
url = 'https://news.google.com/rss/search?q=nifty'

# Parse the RSS feed
feed = feedparser.parse(url)

# Display the feed's title
print(f"Feed Title: {feed.feed.title}")
print(f"Feed Link: {feed.feed.link}")
print(f"Feed Description: {feed.feed.description}\n")

# Iterate through the entries in the feed and display the title, link, and description
for entry in feed.entries:
    print(f"Title: {entry.title}")
    print(f"Link: {entry.link}")
    print(f"Published: {entry.published}")
    print(f"Description: {entry.description}\n")
# Out:
# Feed Title: "nifty" - Google News
# Feed Link: https://news.google.com/search?q=nifty&hl=en-CA&gl=CA&ceid=CA:en
# Feed Description: Google News
#
# Title: Indian shares, including Nifty 50, slip into correction as rate woes adds to sour sentiment - Reuters India
# Link: https://news.google.?oc=5
# Published: Wed, 13 Nov 2024 10:34:01 GMT
# ...
